# %% [markdown]
# # Titanic Dataset Visualization
#
# This notebook demonstrates various visualizations on the Titanic dataset using **Seaborn** and **Matplotlib**.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load Titanic dataset
titanic = sns.load_dataset("titanic")

# Display first few rows
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who adult_male deck  embark_town alive  alone
# 0    man       True  NaN  Southampton    no  False
# 1  woman      False    C    Cherbourg   yes  False
# 2  woman      False  NaN  Southampton   yes   True
# 3  woman      False    C  Southampton   yes  False
# 4    man       True  NaN  Southampton    no   True

# %% [markdown]
# ## Dataset Overview

# %%
titanic.info()
titanic.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     640 non-null    int64
#  1   pclass       640 non-null    int64
#  2   sex          640 non-null    object
#  3   age          506 non-null    float64
#  4   sibsp        640 non-null    int64
#  5   parch        640 non-null    int64
#  6   fare         640 non-null    float64
#  7   embarked     639 non-null    object
#  8   class        639 non-null    category
#  9   who          639 non-null    object
#  10  adult_male   639 non-null    object
#  11  deck         143 non-null    category
#  12  embark_town  638 non-null    object
#  13  alive        639 non-null    object
#  14  alone        639 non-null    object
# dtypes: category(2), float64(2), int64(4), object(7)
# memory usage: 66.9+ KB
#           survived      pclass   sex         age       sibsp       parch  \
# count   640.000000  640.000000   640  506.000000  640.000000  640.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   405         NaN         NaN         NaN
# mean      0.390625    2.307812   NaN   29.966403    0.534375    0.384375
# std       0.488272    0.835781   NaN   14.556328    1.077036    0.806317
# min       0.000000    1.000000   NaN    0.750000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   21.000000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.250000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    5.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# count   640.000000      639    639  639        639  143          638   639
# unique         NaN        3      3    3          2    7            3     2
# top            NaN        S  Third  man       True    C  Southampton    no
# freq           NaN      459    351  379        379   47          458   389
# mean     31.447669      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# std      45.326485      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# min       0.000000      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# 25%       7.925000      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# 50%      15.022900      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# 75%      30.500000      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# max     512.329200      NaN    NaN  NaN        NaN  NaN          NaN   NaN
#
#        alone
# count    639
# unique     2
# top     True
# freq     377
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN

# %%
r=titanic['age'].max()-titanic['age'].min()
r/10
# Out:
# np.float64(7.925)

# %% [markdown]
# ## 📊 Seaborn Visualizations

# %% [markdown]
# ###  Histogram
# A histogram is a graphical representation of the distribution of numerical data. It divides the data into intervals called bins, and the height of each bin represents the frequency (or count) of data points within that interval.
# ### Distribution of Age (Histogram + KDE)
# Shows how passenger ages are distributed.

# %%
plt.figure(figsize=(8,5))
sns.histplot(titanic['age'].dropna(), bins=10, kde=True)
plt.title("Distribution of Passenger Ages")
plt.show()

# %% [markdown]
# ###  Count plot
# Count plot is a type of bar chart used to show the number of occurrences (frequency) of each category in a dataset.
# Useful for categorical data (like gender, class, species).Each bar represents a category, and its height = number of observations in that category.
#
# ### Count of Passengers by Class

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="class", data=titanic, hue="class", palette="Set2", legend=True)

plt.title("Passenger Count by Class")
plt.show()

# %% [markdown]
# ### Survival Rate by Gender
# A bar plot is used to visualize numerical summaries (like mean, sum) for categorical data.
# estimator=np.sum   # <-- Use sum instead of mean

# %%
import numpy as np
plt.figure(figsize=(6,4))
sns.barplot(x="sex", y="survived", data=titanic,hue="sex" , palette="coolwarm")
plt.title("Survival Rate by Gender")
plt.show()

# %% [markdown]
# ### Boxplot of Age by Class
# A boxplot (or whisker plot) is a graphical representation of the distribution of a dataset.
# It highlights the median, quartiles, and outliers in the data.
#
# [![Untitled-2.webp](https://i.postimg.cc/kg5MBk5M/Untitled-2.webp)](https://postimg.cc/QHRZzY5v)

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x="class", y="age", data=titanic, hue="class" ,palette="pastel")
plt.title("Age Distribution Across Classes")
plt.show()

# %% [markdown]
# ### Scatter Plot
# A scatter plot is a type of data visualization that displays the relationship between two numerical variables using points (dots) on a Cartesian coordinate system.
#
# ### Patterns & Relationships
# Scatter plots reveal trends, correlations, or clusters.
# The direction of the pattern (upward, downward, or random) shows whether variables are positively correlated, negatively correlated, or uncorrelated.
# ### Types of Relationships in Scatter Plots
# Positive correlation – as 𝑥 increases, y also increases.
# Negative correlation – as x increases,y decreases.
# No correlation – no visible relationship between 𝑥 and y.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
sns.scatterplot(
    x="age", 
    y="survived", 
    data=titanic, 
    hue="sex",        # color by gender
    style="class",    # shape by passenger class
    palette="coolwarm",
    alpha=0.7
)
plt.title("Scatter Plot: Age vs Survival (Colored by Gender, Styled by Class)")
plt.xlabel("Age")
plt.ylabel("Survival (0 = No, 1 = Yes)")
plt.show()

# %% [markdown]
# ### Line plotabs
# A line plot is great for showing trends or changes in a numerical variable across categories or time

# %%
# Compute average fare per class
fare_by_class = titanic.groupby('class')['fare'].mean().reset_index()

plt.figure(figsize=(8,5))
sns.lineplot(
    x='class', 
    y='fare', 
    data=fare_by_class, 
    marker='o',        # show points on line
    color='blue'
)
plt.title("Average Fare by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Average Fare")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11884\288801721.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   fare_by_class = titanic.groupby('class')['fare'].mean().reset_index()

# %% [markdown]
# ### Violin Plot of Age by Gender & Class
# A Violin Plot is a statistical graph that combines the features of a box plot and a kernel density plot. It is used to visualize the distribution, probability density, and summary statistics of a dataset.

# %%
plt.figure(figsize=(8,5))
sns.violinplot(x="class", y="age", hue="sex", data=titanic, split=True, palette="muted")
plt.title("Age Distribution by Class and Gender")
plt.show()

# %% [markdown]
# ### Stripplot (shows distribution with possible overlaps)
# A strip plot is a type of categorical scatter plot used to display the distribution of individual data points for a given categorical variable. It is commonly used when the dataset is small or when it’s important to show all individual observations rather than summaries.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Stripplot of Age by Class
plt.figure(figsize=(8,5))
sns.stripplot(x="class", y="age", data=titanic, hue="class",jitter=True, palette="Set2")
plt.title("Stripplot of Age across Passenger Classes")
plt.show()

# %% [markdown]
# ### Swarmplot (like stripplot but avoids overlaps)
# A swarm plot is a categorical scatter plot, similar to a strip plot, but with a key improvement: it adjusts the position of points along the categorical axis so that they do not overlap. This makes it easier to see the exact distribution of individual observations.

# %%
plt.figure(figsize=(8,5))
sns.swarmplot(x="class", y="age", data=titanic,hue="class", palette="Set1")
plt.title("Swarmplot of Age across Passenger Classes")
plt.show()

# %% [markdown]
# ### Heatmap
# A heatmap is a color-coded table that makes numerical relationships easy to interpret, especially for correlations or frequency distributions.

# %%
plt.figure(figsize=(10,6))
sns.heatmap(titanic.corr(numeric_only=True), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap of Titanic Data")
plt.show()

# %% [markdown]
# ### Cluster Map
# A Cluster Map is very useful for EDA because it combines a heatmap with hierarchical clustering. It groups similar rows/columns together so patterns in correlations (or any matrix-like data) become clear.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select only numeric columns
titanic_numeric = titanic.select_dtypes(include=["float64", "int64"])

# Compute correlation matrix
corr = titanic_numeric.corr()

# Plot clustermap
sns.clustermap(corr, annot=True, cmap="coolwarm", figsize=(8,6))
plt.suptitle("Cluster Map of Titanic Numerical Feature Correlations", y=1.02)
plt.show()

# %% [markdown]
# ### Pairplot
# A pair plot is a visualization that shows pairwise relationships between multiple numerical variables in a dataset. It is essentially a matrix of scatter plots where:Each cell in the matrix is a scatter plot of one variable vs another.
# The diagonal usually shows the distribution of each variable (histogram or KDE).

# %%
sns.pairplot(titanic[["age", "fare", "survived", "pclass"]].dropna(), hue="survived")
plt.suptitle("Pairplot of Selected Titanic Features", y=1.02)
plt.show()

# %% [markdown]
# ### Sub plot
# A subplot allows you to display multiple plots in a single figure, arranged in a grid layout. This is very useful when comparing different variables, categories, or visualization types side by side.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load Titanic dataset
titanic = sns.load_dataset("titanic")

# Create figure with 2x2 subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# 1. Histogram of Age
sns.histplot(titanic["age"], kde=True, bins=30, ax=axes[0,0], color="skyblue")
axes[0,0].set_title("Age Distribution")

# 2. Boxplot of Fare by Class
sns.boxplot(x="class", y="fare", data=titanic, ax=axes[0,1], palette="Set2")
axes[0,1].set_title("Fare by Class")

# 3. Countplot of Gender
sns.countplot(x="sex", data=titanic, ax=axes[1,0], palette="pastel")
axes[1,0].set_title("Count of Male vs Female")

# 4. Scatter plot Age vs Fare
sns.scatterplot(x="age", y="fare", data=titanic, hue="class", ax=axes[1,1], palette="Set1")
axes[1,1].set_title("Age vs Fare (by Class)")

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11884\3082768140.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="class", y="fare", data=titanic, ax=axes[0,1], palette="Set2")
# C:\Users\HP\AppData\Local\Temp\ipykernel_11884\3082768140.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="sex", data=titanic, ax=axes[1,0], palette="pastel")

# %% [markdown]
# ## 📈 Basic Matplotlib Visualizations

# %% [markdown]
# ### Age Histogram

# %%
plt.figure(figsize=(8,5))
plt.hist(titanic['age'].dropna(), bins=30, color='skyblue', edgecolor='black')
plt.title("Age Distribution (Matplotlib)")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Survival Pie Chart

# %%
survival_counts = titanic['survived'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(survival_counts, labels=["Not Survived","Survived"], autopct='%1.1f%%', colors=["lightcoral","lightgreen"])
plt.title("Survival Distribution (Pie Chart)")
plt.show()

# %% [markdown]
# ### Average Fare by Class (Bar Chart)

# %%
avg_fare = titanic.groupby("class")["fare"].mean()
plt.figure(figsize=(6,4))
plt.bar(avg_fare.index, avg_fare.values, color=["gold","silver","brown"])
plt.title("Average Fare by Class")
plt.xlabel("Class")
plt.ylabel("Average Fare")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11884\1570310216.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_fare = titanic.groupby("class")["fare"].mean()

# %% [markdown]
# ### Line Plot of Fare vs Age

# %%
plt.figure(figsize=(8,5))
plt.plot(titanic["age"], titanic["fare"], "o", markersize=4, alpha=0.5)
plt.title("Fare vs Age (Scatter/Line Plot)")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.show()

# %% [markdown]
# # 📊 Supermarket Sales Data Visualization
#
# The growth of supermarkets in the most populated cities is increasing, and market competition is also high.
# The dataset provided is from one of the historical supermarket companies, containing sales records across **three different branches**.
#
# As a **Data Scientist**, the task is to analyze and visualize this dataset using different types of plots.
#
# ---
#
# ### 📂 Dataset Columns
# - **Branch**
# - **City**
# - **Customer type**
# - **Gender**
# - **Unit price**
# - **Quantity**
# - **Tax (5%)**
# - **Total**
#
# ---
#
# ### 📝 Dataset
#
# | Branch | City       | Customer type | Gender | Unit price | Quantity | Tax 5%   | Total     |
# |--------|-----------|---------------|--------|------------|----------|----------|-----------|
# | A      | Yangon    | Member        | Female | 74.69      | 7        | 26.1415  | 548.9715  |
# | C      | Naypyitaw | Normal        | Female | 15.28      | 5        | 3.82     | 80.22     |
# | A      | Yangon    | Normal        | Male   | 46.33      | 7        | 16.2155  | 340.5255  |
# | A      | Yangon    | Member        | Male   | 58.22      | 8        | 23.288   | 489.048   |
# | A      | Yangon    | Normal        | Male   | 86.31      | 7        | 30.2085  | 634.3785  |
# | C      | Naypyitaw | Normal        | Male   | 85.39      | 7        | 29.8865  | 627.6165  |
# | A      | Yangon    | Member        | Female | 68.84      | 6        | 20.652   | 433.692   |
# | C      | Naypyitaw | Normal        | Female | 73.56      | 10       | 36.78    | 772.38    |
# | A      | Yangon    | Member        | Female | 36.26      | 2        | 3.626    | 76.146    |
# | B      | Mandalay  | Member        | Female | 54.84      | 3        | 8.226    | 172.746   |
# | B      | Mandalay  | Member        | Female | 14.48      | 4        | 2.896    | 60.816    |
# | B      | Mandalay  | Member        | Male   | 25.51      | 4        | 5.102    | 107.142   |
# | A      | Yangon    | Normal        | Female | 46.95      | 5        | 11.7375  | 246.4875  |
# | A      | Yangon    | Normal        | Male   | 43.19      | 10       | 21.595   | 453.495   |
# | A      | Yangon    | Normal        | Female | 71.38      | 10       | 35.69    | 749.49    |
# | B      | Mandalay  | Member        | Female | 93.72      | 6        | 28.116   | 590.436   |
# | A      | Yangon    | Member        | Female | 68.93      | 7        | 24.1255  | 506.6355  |
#
# ---
#
# ## 🔍 Visualization Tasks
#
# 1. **Line Plot** → Plot the line plot between `Unit price` and `Total`.
# 2. **Scatter Plot** → Plot the scatter plot between `Unit price` and `Total`.
# 3. **Linear Regression Plot** → Illustrate the linear relationship between `Unit price` and `Quantity`.
# 4. **Bar Plot (Gender)** → Plot the number of **Male** and **Female** customers.
# 5. **Bar Plot (Customer Type)** → Plot the number of **Member** and **Normal** customers.
# 6. **Bar Plot (Average Unit Price by Gender)** → Plot the average `Unit price` of **Male** vs **Female** customers.
# 7. **Box Plot (City-wise Unit Price)** → Show the distributions of `Unit price` across different cities.
# 8. **Swarm Plot** → Visualize the relationship between **Customer type** (Member/Normal) and `Quantity`.
# 9. **Violin Plot** → Visualize the relationship between **Customer type** and `Quantity` using a violin plot.
# 10. **Subplots** → Combine outputs of **Swarm Plot (Task 8)** and **Violin Plot (Task 9)** into a single subplot layout.
#
# ---

# %%
# 📊 Supermarket Sales Data Visualization
# Author: Lochana K & Paapu 💕

# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ---------------------------------------
# 1️⃣ Create the dataset
# ---------------------------------------
data = {
    'Branch': ['A', 'C', 'A', 'A', 'A', 'C', 'A', 'C', 'A', 'B', 'B', 'B', 'A', 'A', 'A', 'B', 'A'],
    'City': ['Yangon', 'Naypyitaw', 'Yangon', 'Yangon', 'Yangon', 'Naypyitaw', 'Yangon', 'Naypyitaw',
             'Yangon', 'Mandalay', 'Mandalay', 'Mandalay', 'Yangon', 'Yangon', 'Yangon', 'Mandalay', 'Yangon'],
    'Customer type': ['Member', 'Normal', 'Normal', 'Member', 'Normal', 'Normal', 'Member', 'Normal', 'Member',
                      'Member', 'Member', 'Member', 'Normal', 'Normal', 'Normal', 'Member', 'Member'],
    'Gender': ['Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Female', 'Female',
               'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female'],
    'Unit price': [74.69, 15.28, 46.33, 58.22, 86.31, 85.39, 68.84, 73.56, 36.26, 54.84, 14.48, 25.51,
                   46.95, 43.19, 71.38, 93.72, 68.93],
    'Quantity': [7, 5, 7, 8, 7, 7, 6, 10, 2, 3, 4, 4, 5, 10, 10, 6, 7],
    'Tax (5%)': [26.1415, 3.82, 16.2155, 23.288, 30.2085, 29.8865, 20.652, 36.78, 3.626, 8.226, 2.896, 5.102,
                 11.7375, 21.595, 35.69, 28.116, 24.1255],
    'Total': [548.9715, 80.22, 340.5255, 489.048, 634.3785, 627.6165, 433.692, 772.38, 76.146, 172.746, 60.816,
              107.142, 246.4875, 453.495, 749.49, 590.436, 506.6355]
}

df = pd.DataFrame(data)

# ---------------------------------------
# 2️⃣ Line Plot – Unit price vs Total
# ---------------------------------------
plt.figure(figsize=(8,5))
plt.plot(df['Unit price'], df['Total'], marker='o', color='teal')
plt.title('Line Plot: Unit Price vs Total')
plt.xlabel('Unit Price')
plt.ylabel('Total')
plt.grid(True)
plt.show()

# ---------------------------------------
# 3️⃣ Scatter Plot – Unit price vs Total
# ---------------------------------------
plt.figure(figsize=(8,5))
sns.scatterplot(x='Unit price', y='Total', data=df, color='purple', s=80)
plt.title('Scatter Plot: Unit Price vs Total')
plt.show()

# ---------------------------------------
# 4️⃣ Linear Regression Plot – Unit price vs Quantity
# ---------------------------------------
plt.figure(figsize=(8,5))
sns.regplot(x='Unit price', y='Quantity', data=df, color='green')
plt.title('Linear Regression: Unit Price vs Quantity')
plt.show()

# ---------------------------------------
# 5️⃣ Bar Plot (Gender count)
# ---------------------------------------
plt.figure(figsize=(6,4))
sns.countplot(x='Gender', data=df, palette='pastel')
plt.title('Number of Male and Female Customers')
plt.show()

# ---------------------------------------
# 6️⃣ Bar Plot (Customer Type count)
# ---------------------------------------
plt.figure(figsize=(6,4))
sns.countplot(x='Customer type', data=df, palette='Set2')
plt.title('Number of Member vs Normal Customers')
plt.show()

# ---------------------------------------
# 7️⃣ Bar Plot – Average Unit Price by Gender
# ---------------------------------------
plt.figure(figsize=(6,4))
sns.barplot(x='Gender', y='Unit price', data=df, estimator='mean', palette='cool')
plt.title('Average Unit Price by Gender')
plt.show()

# ---------------------------------------
# 8️⃣ Box Plot – City-wise Unit Price
# ---------------------------------------
plt.figure(figsize=(7,5))
sns.boxplot(x='City', y='Unit price', data=df, palette='Accent')
plt.title('City-wise Distribution of Unit Price')
plt.show()

# ---------------------------------------
# 9️⃣ Swarm Plot – Customer Type vs Quantity
# ---------------------------------------
plt.figure(figsize=(7,5))
sns.swarmplot(x='Customer type', y='Quantity', data=df, palette='husl', size=7)
plt.title('Swarm Plot: Customer Type vs Quantity')
plt.show()

# ---------------------------------------
# 🔟 Violin Plot – Customer Type vs Quantity
# ---------------------------------------
plt.figure(figsize=(7,5))
sns.violinplot(x='Customer type', y='Quantity', data=df, palette='muted')
plt.title('Violin Plot: Customer Type vs Quantity')
plt.show()

# ---------------------------------------
# 🧩 Subplots – Swarm & Violin together
# ---------------------------------------
fig, axes = plt.subplots(1, 2, figsize=(12,5))

sns.swarmplot(ax=axes[0], x='Customer type', y='Quantity', data=df, palette='husl', size=7)
axes[0].set_title('Swarm Plot: Customer Type vs Quantity')

sns.violinplot(ax=axes[1], x='Customer type', y='Quantity', data=df, palette='muted')
axes[1].set_title('Violin Plot: Customer Type vs Quantity')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11884\344441564.py:62: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender', data=df, palette='pastel')
# C:\Users\HP\AppData\Local\Temp\ipykernel_11884\344441564.py:70: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Customer type', data=df, palette='Set2')
# C:\Users\HP\AppData\Local\Temp\ipykernel_11884\344441564.py:78: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Gender', y='Unit price', data=df, estimator='mean', palette='cool')
# C:\Users\HP\AppData\Local\Temp\ipykernel_11884\344441564.py:86: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='City', y='Unit price', data=df, palette='Accent')
# C:\Users\HP\AppData\Local\Temp\ipykernel_11884\344441564.py:94: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x='Customer type', y='Quantity', data=df, palette='husl', size=7)
# C:\Users\HP\AppData\Local\Temp\ipykernel_11884\344441564.py:102: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Customer type', y='Quantity', data=df, palette='muted')
# C:\Users\HP\AppData\Local\Temp\ipykernel_11884\344441564.py:111: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(ax=axes[0], x='Customer type', y='Quantity', data=df, palette='husl', size=7)
# C:\Users\HP\AppData\Local\Temp\ipykernel_11884\344441564.py:114: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(ax=axes[1], x='Customer type', y='Quantity', data=df, palette='muted')
